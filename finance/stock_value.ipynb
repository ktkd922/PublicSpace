# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

df = pd.read_csv('emaxis_slim_all_country.csv', encoding='shift_jis',
                 index_col='日付', parse_dates=True)
df.head()
# Out:
#              基準価額
# 日付
# 2018-10-31  10000
# 2018-11-01  10077
# 2018-11-02  10209
# 2018-11-05  10228
# 2018-11-06  10259

# %%
plt.plot(df.index, df['基準価額'])
plt.xlabel('date')
plt.ylabel('value')
plt.show()
